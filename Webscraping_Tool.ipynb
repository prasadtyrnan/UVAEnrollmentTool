# %%
import requests
url = input("Paste URL: ")
page = requests.get(url)
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
txt = soup.get_text()
print(txt)
# Out:
# Paste URL: https://rabi.phys.virginia.edu/mySIS/CS2/page.php?Semester=1202&Type=Group&Group=KINE&Print=
#
#
#
#
#
#
# UVa Class Schedule -Complete Schedule of Classes for Kinesiology Department - Spring 2020(Unofficial, Lou's List)
#
# <!--
# function MM_jumpMenuGo(objId,targ,restore){ //v9.0
#   var selObj = null;  with (document) {
#   if (getElementById) selObj = getElementById(objId);
#   if (selObj) eval(targ+".location='"+selObj.options[selObj.selectedIndex].value+"'");
#   if (restore) selObj.selectedIndex=0; }
# }
# //-->
#
#
# function toggledetails(MN) {
# if($('tr.'+MN).is(':visible')) {
# 	$('tr.'+MN).hide();
# 	$('img.I'+MN).attr('src', 'images/plus.gif');
# 	$('tr.B'+MN).show();
# 	}
# else {
# 	$('tr.'+MN).show();
# 	$('img.I'+MN).attr('src', 'images/minus.gif');
# 	$('tr.B'+MN).hide();
# 	}
# }
# function hidenow(MN) {
# 	$('tr.'+MN).hide();
# 	$('img.I'+MN).attr('src', 'images/plus.gif');
# 	$('tr.B'+MN).show();
# }
# function expandall() {
# 	$('tr.S').show();
# ...
